# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint


BASE_URL = "https://timesofindia.indiatimes.com/"
IMG_URL = "https://static.toiimg.com/thumb/msid-{},width-500,resizemode-4/{}.jpg"

# %%
data = []

r = requests.get(BASE_URL)
soup = BeautifulSoup(r.content, "html5lib")
feeds = soup.find_all("div", class_="col_l_6")  # type: ignore

for feed in feeds:
	try:
		a = feed.find("a")
		tag = a["href"].split("/")[3]
		title = a.find("figcaption").get_text()
		img_id = a["href"].split("/")[-1][:-4]
		img_url = IMG_URL.format(img_id, img_id)
		data.append({"title": title, "tag": tag, "img_url": img_url})
	except Exception as e:
		print(e)

pprint(data)
# Out:
# 'NoneType' object is not subscriptable
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# 'NoneType' object has no attribute 'get_text'
# [{'img_url': 'https://static.toiimg.com/thumb/msid-90885728,width-500,resizemode-4/90885728.jpg',
#   'tag': 'india',
#   'title': 'Live: UP govt makes wearing of mask compulsory in NCR'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90794801,width-500,resizemode-4/90794801.jpg',
#   'tag': 'business',
#   'title': 'How to invest in foreign stocks directly'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90885732,width-500,resizemode-4/90885732.jpg',
#   'tag': 'world',
#   'title': 'Live: 6 dead, 11 wounded in Russian strikes on Lviv'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90902718,width-500,resizemode-4/90902718.jpg',
#   'tag': 'home',
#   'title': 'Why Media means more than Journalism today'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90899864,width-500,resizemode-4/90899864.jpg',
#   'tag': 'india',
#   'title': 'With 2 degrees, students can customise learning: UGC'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90874445,width-500,resizemode-4/90874445.jpg',
#   'tag': 'india',
#   'title': 'Why less and less rainfall is called normal monsoon'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90907545,width-500,resizemode-4/90907545.jpg',
#   'tag': 'sports',
#   'title': "Watch: 3 wickets, no runs - Umran's fiery 20th over heroics"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90896801,width-500,resizemode-4/90896801.jpg',
#   'tag': 'slideshows',
#   'title': '11 new features WhatsApp announced in 2022'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90850114,width-500,resizemode-4/90850114.jpg',
#   'tag': 'spotlight',
#   'title': 'CRED International Travel Sale: From 15-18 April'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-amazon-bestsel,width-500,resizemode-4/amazon-bestsel.jpg',
#   'tag': 'amazon-bestsellers',
#   'title': 'First day of the week calls for browsing the latest deals!'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-galaxy-f23-frevolu,width-500,resizemode-4/galaxy-f23-frevolu.jpg',
#   'tag': 'spotlight',
#   'title': 'Join the Frevolution with #GalaxyF23 5G'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90900080,width-500,resizemode-4/90900080.jpg',
#   'tag': 'city',
#   'title': '34 FIRs against 40 Chinese, 110 others for fraud'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90399331,width-500,resizemode-4/90399331.jpg',
#   'tag': 'how-to',
#   'title': 'How to make correction in Aadhaar card details online'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90907737,width-500,resizemode-4/90907737.jpg',
#   'tag': 'tv',
#   'title': 'Munawar Faruqui breaks down as he reveals how his mother died'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90647531,width-500,resizemode-4/90647531.jpg',
#   'tag': 'featured',
#   'title': 'Explainer: What is Clickjacking and how hackers use it'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90904770,width-500,resizemode-4/90904770.jpg',
#   'tag': 'web-series',
#   'title': "The Archies: Suhana, Agastya & Khushi's film goes on floors"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90909846,width-500,resizemode-4/90909846.jpg',
#   'tag': 'entertainment',
#   'title': 'Anushka relishes Bengali delight Panta Bhat'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90909022,width-500,resizemode-4/90909022.jpg',
#   'tag': 'entertainment',
#   'title': "Varun's Jug Jugg Jeeyo to take a dig at Kalank?"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90906651,width-500,resizemode-4/90906651.jpg',
#   'tag': 'entertainment',
#   'title': "B'wood brides who ditched wedding lehenga"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90907737,width-500,resizemode-4/90907737.jpg',
#   'tag': 'tv',
#   'title': "Munawar's mother passed away after consuming acid"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90900641,width-500,resizemode-4/90900641.jpg',
#   'tag': 'city',
#   'title': 'Uttar Pradesh: Boy, 14, beheaded by sister’s friends over '
#            '‘affair’, 2 held'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90906844,width-500,resizemode-4/90906844.jpg',
#   'tag': 'videos',
#   'title': "Mumbai: BJP's 'Poll Khol' agitation to expose BMC corruption"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90906844,width-500,resizemode-4/90906844.jpg',
#   'tag': 'videos',
#   'title': "Mumbai: BJP's 'Poll Khol' agitation to expose BMC corruption"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90906542,width-500,resizemode-4/90906542.jpg',
#   'tag': 'sports',
#   'title': 'IPL: Overseas player of Delhi Capitals tests COVID positive, '
#            "squad's travel to Pune delayed"},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90906659,width-500,resizemode-4/90906659.jpg',
#   'tag': 'business',
#   'title': 'WPI inflation hits 4-month high of 14.55% in March'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90909391,width-500,resizemode-4/90909391.jpg',
#   'tag': 'world',
#   'title': '26 arrested after violent Sweden protests: Police'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90863666,width-500,resizemode-4/90863666.jpg',
#   'tag': 'religion',
#   'title': 'Hanuman Jayanti 2022 today: Auspicious day to remove Mangal Dosha, '
#            'Puja Moola Mantra, Muhurta time'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90891595,width-500,resizemode-4/90891595.jpg',
#   'tag': 'life-style',
#   'title': 'How to make Gulab Jamun with just 3 ingredients'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90903432,width-500,resizemode-4/90903432.jpg',
#   'tag': 'life-style',
#   'title': 'Diet and fitness habits of cricketer Dinesh Karthik'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90907989,width-500,resizemode-4/90907989.jpg',
#   'tag': 'auto',
#   'title': "BMW X4 Silver Shadow Edition launched at Rs 71.90 lakh: What's "
#            'new?'},
#  {'img_url': 'https://static.toiimg.com/thumb/msid-90902718,width-500,resizemode-4/90902718.jpg',
#   'tag': 'home',
#   'title': 'Why Media means more than Journalism today'}]
